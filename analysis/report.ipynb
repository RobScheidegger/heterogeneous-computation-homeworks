# %% [markdown]
# # APMA2822B Homework 1 - Hammad Izhar + Robert Scheidegger
#
# #TODO: Intro text (HAMMAD)

# %%
# Initial block: Load the CSV file from the data folder (oscar_data.csv)

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('../data/oscar_data.csv', encoding='latin-1')
df['flops'] = 2 * df['n'] * df['n'] / df['time_us'] * 1e6
df['gflops'] = df['flops'] / 1e9
df['iops'] = 5 * df['n'] * df['m'] / df['time_us'] * 1e6

# %% [markdown]
# ## Roof-line Analysis
#
# For the purposes of this analyis, we will look at the results from the `DisjointMemoryAllocator`, `RowColumnMultiplier`, and size `100000 x 10000` (the largest of the sizes that we have tested for this assignment).
#
# We see that the code for the `RowColumnMultiplier` is as follows (exluding timing and parallelization primitives; the exact code can be found in `include/multipliers.hpp`):
#
# ```
# for (uint32_t i = 0; i < n; i++) {
#     for (uint32_t j = 0; j < m; j++) {
#         output[i] += matrix[i][j] * vector[j];
#     }
# }
# ```
#
# To compute the arithmetic intensity, we first consider all of the IOps:
#
# 1. Load `matrix[i]` (since this is a pointer, and is needed to find the column value)
# 2. Load `matrix[i][j]`
# 3. Load `vector[j]`
# 4. Save `matrix[i][j] * vector[j]` into a temporary variable
# 5. Load `output[i]` (can add this to the temporary variable)
# 6. Save `output[i]`
#
# This gives 6 input/output operations, which each act on 4 bytes (since these are all `float` values), giving a total of `24` bytes transferred. Further, the floating point operations are:
#
# 1. Multiply `RESULT = matrix[i][j] * vector[j]`
# 2. Add `RESULT + output[i]`
#
# This gives an overall arithmetic intensity (AI) of `AI = 2 / 24 = 1 / 12`. By the example numbers given we should expect the limiting point of the roof-line plot to be at `10^12 / (160 * 10^9) = 6.25`, so clearly we are within the memory bandwidth limiting section of the roof-line plot. Thus, we should expect a peak GFLOPs rate of `1000 * (1/12) = 83.3` GFLOPs. From the table below, you can see that out actual peak occurred at 110 GFLOPs when using 32 threads to compute the result, which is certainly in line with the expectation (especially since the TFLOPs estimate is non sync'd to the OSCAR hardware we are actually running on).
#
# This can be seen in the table and actual roof-line plot below:

# %%
# Compute the roof-line plot for the analysis above.
subset = df[df['allocator'] == 'ContiguousMemoryAllocator']
subset = subset[subset['multiplier'] == 'RowColumnMultiplier']
subset = subset[subset['m'] == 10000]
subset = subset[subset['n'] == 100000]

# Plot the roof-line plot
# TODO: Hammad

subset
# Out:
#            n      m  threads                  allocator           multiplier  \
# 1908  100000  10000        1  ContiguousMemoryAllocator  RowColumnMultiplier
# 1916  100000  10000        2  ContiguousMemoryAllocator  RowColumnMultiplier
# 1924  100000  10000        4  ContiguousMemoryAllocator  RowColumnMultiplier
# 1932  100000  10000        8  ContiguousMemoryAllocator  RowColumnMultiplier
# 1940  100000  10000       16  ContiguousMemoryAllocator  RowColumnMultiplier
# 1948  100000  10000       32  ContiguousMemoryAllocator  RowColumnMultiplier
# 1956  100000  10000       64  ContiguousMemoryAllocator  RowColumnMultiplier
# 1964  100000  10000        1  ContiguousMemoryAllocator  RowColumnMultiplier
# 1972  100000  10000        2  ContiguousMemoryAllocator  RowColumnMultiplier
# 1980  100000  10000        4  ContiguousMemoryAllocator  RowColumnMultiplier
# 1988  100000  10000        8  ContiguousMemoryAllocator  RowColumnMultiplier
# 1996  100000  10000       16  ContiguousMemoryAllocator  RowColumnMultiplier
# 2004  100000  10000       32  ContiguousMemoryAllocator  RowColumnMultiplier
# 2012  100000  10000       64  ContiguousMemoryAllocator  RowColumnMultiplier
#
#       iterations       time_us     stdev_us         flops      gflops  \
# 1908          10  2.734335e+06          NaN  7.314393e+09    7.314393
# 1916          10  1.361415e+06   512.000000  1.469060e+10   14.690600
# 1924          10  6.826735e+05     0.000000  2.929658e+10   29.296582
# 1932          10  3.422639e+05    90.509666  5.843444e+10   58.434441
# 1940          10  1.708000e+05   169.328079  1.170960e+11  117.096019
# 1948          10  1.782432e+05  9558.630859  1.122062e+11  112.206242
# 1956          10  2.011124e+05  5523.685547  9.944687e+10   99.446873
# 1964          10  2.730175e+06          NaN  7.325537e+09    7.325537
# 1972          10  1.365162e+06   362.038666  1.465027e+10   14.650271
# 1980          10  6.829017e+05   256.000000  2.928679e+10   29.286792
# 1988          10  3.422754e+05     0.000000  5.843248e+10   58.432478
# 1996          10  1.713957e+05   263.878754  1.166890e+11  116.689040
# 2004          10  1.766522e+05  9967.678711  1.132168e+11  113.216816
# 2012          10  2.004919e+05  5808.506836  9.975465e+10   99.754650
#
#               iops
# 1908  1.828598e+09
# 1916  3.672650e+09
# 1924  7.324145e+09
# 1932  1.460861e+10
# 1940  2.927400e+10
# 1948  2.805156e+10
# 1956  2.486172e+10
# 1964  1.831384e+09
# 1972  3.662568e+09
# 1980  7.321698e+09
# 1988  1.460812e+10
# 1996  2.917226e+10
# 2004  2.830420e+10
# 2012  2.493866e+10

# %% [markdown]
# ## Performance Analysis
#
# To test our
#
# This leads to a total of 2016 possible combinations of parameters, and for each of these we performed an experiment on oscar (in a single script, which iterated through all of the possible benchmark configurations). A warmup/dummy computation was added to each  was added
#
# To ensure consistency within a run, each was repeated for `10` iterations, and the mean and standard deviations of the runtimes were computed. A sample of the data that we collected is seen below:

# %%
df
df[df['time_us'] != 0].sort_values('flops', ascending=False)
# Out:
#            n      m  threads                   allocator           multiplier  \
# 1708  100000      1        8   ContiguousMemoryAllocator  RowColumnMultiplier
# 1706  100000      1        8  DisjointRowMemoryAllocator  RowColumnMultiplier
# 1700  100000      1        4   ContiguousMemoryAllocator  RowColumnMultiplier
# 1704  100000      1        8     DisjointMemoryAllocator  RowColumnMultiplier
# 1724  100000      1       32   ContiguousMemoryAllocator  RowColumnMultiplier
# ...      ...    ...      ...                         ...                  ...
# 91         1     10       16  DisjointRowMemoryAllocator  ColumnRowMultiplier
# 313        1  10000       16     DisjointMemoryAllocator  ColumnRowMultiplier
# 262        1  10000       16         MmapMemoryAllocator  RowColumnMultiplier
# 256        1  10000       16     DisjointMemoryAllocator  RowColumnMultiplier
# 204        1   1000       16   ContiguousMemoryAllocator  RowColumnMultiplier
#
#       iterations      time_us     stdev_us         flops        gflops  \
# 1708          10    50.099998     2.022457  3.992016e+14  3.992016e+05
# 1706          10    85.500000    10.452272  2.339181e+14  2.339181e+05
# 1700          10    93.800003     2.357874  2.132196e+14  2.132196e+05
# 1704          10   110.000000    35.437267  1.818182e+14  1.818182e+05
# 1724          10   126.199997    26.049194  1.584786e+14  1.584786e+05
# ...          ...          ...          ...           ...           ...
# 91            10  8447.700195  1202.128174  2.367508e+02  2.367508e-07
# 313           10  8459.099609  1211.121826  2.364318e+02  2.364318e-07
# 262           10  8461.599609  1215.756592  2.363619e+02  2.363619e-07
# 256           10  8489.299805  1232.574585  2.355907e+02  2.355907e-07
# 204           10  8838.400391  1563.508911  2.262853e+02  2.262853e-07
#
#               iops
# 1708  9.980040e+09
# 1706  5.847953e+09
# 1700  5.330490e+09
# 1704  4.545455e+09
# 1724  3.961965e+09
# ...            ...
# 91    5.918771e+03
# 313   5.910795e+06
# 262   5.909048e+06
# 256   5.889767e+06
# 204   5.657132e+05
#
# [1969 rows x 11 columns]
